# %% [markdown]
# N=1

# %%
import json
import sys
from pathlib import Path
sys.path.append(str(Path("../../../../")))
from research_szz_cregit.models.commit_map import CommitMap
from research_szz_cregit.repositories.commit_map.impl import CommitMapRepository
import copy

BASE_DIR = Path().resolve().parent.parent.parent.parent
DATABASE_DIR = BASE_DIR / "dataset" / "databases" / "developer-informed-oracle" / "1token"

with open(
    BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_original.json",
    "r",
) as f:
    bugfix_commits = json.load(f)

res_original = []
res_cregit = []

for bugfix_commit in bugfix_commits:
    original_bugfix_commit = copy.deepcopy(bugfix_commit)
    print(bugfix_commit["repo_name"])

    owner, project = bugfix_commit["repo_name"].split("/")

    commit_map_repository = CommitMapRepository(
        DATABASE_DIR / Path(f"{owner}/{project}/{project}-cregit.db")
    )

    commit_map = commit_map_repository.get_all()
    # cregit to original
    hashmaped_commit_map = CommitMap.get_cid_hashmap(commit_map)
    # original to cregit
    hashmaped_commit_map_from_original = CommitMap.get_cid_hashmap_from_original_cid(
        commit_map
    )

    try:
        bugfix_commit["fix_commit_hash"] = hashmaped_commit_map_from_original[
            bugfix_commit["fix_commit_hash"]
        ].cid
        bugfix_commit["bug_commit_hash"] = [
            hashmaped_commit_map_from_original[commit].cid
            for commit in bugfix_commit["bug_commit_hash"]
        ]


        res_cregit.append(bugfix_commit)
        res_original.append(original_bugfix_commit)
    except KeyError:
        print(
            f"KeyError on {bugfix_commit['repo_name']} {bugfix_commit['fix_commit_hash']}"
        )

with open(BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_1token.json", "w") as f:
    json.dump(res_cregit, f, indent=4)
# Out:
# apache/commons-cli
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# apache/commons-codec
# ...

# %% [markdown]
# N=2

# %%
import json
import sys
from pathlib import Path
sys.path.append(str(Path("../../../../")))
from research_szz_cregit.models.commit_map import CommitMap
from research_szz_cregit.repositories.commit_map.impl import CommitMapRepository
import copy

BASE_DIR = Path().resolve().parent.parent.parent.parent
DATABASE_DIR = BASE_DIR / "dataset" / "databases" / "developer-informed-oracle" / "2token"

with open(
    BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_original.json",
    "r",
) as f:
    bugfix_commits = json.load(f)

res_original = []
res_cregit = []

for bugfix_commit in bugfix_commits:
    original_bugfix_commit = copy.deepcopy(bugfix_commit)
    print(bugfix_commit["repo_name"])

    owner, project = bugfix_commit["repo_name"].split("/")

    commit_map_repository = CommitMapRepository(
        DATABASE_DIR / Path(f"{owner}/{project}/{project}-cregit.db")
    )

    commit_map = commit_map_repository.get_all()
    # cregit to original
    hashmaped_commit_map = CommitMap.get_cid_hashmap(commit_map)
    # original to cregit
    hashmaped_commit_map_from_original = CommitMap.get_cid_hashmap_from_original_cid(
        commit_map
    )

    try:
        bugfix_commit["fix_commit_hash"] = hashmaped_commit_map_from_original[
            bugfix_commit["fix_commit_hash"]
        ].cid
        bugfix_commit["bug_commit_hash"] = [
            hashmaped_commit_map_from_original[commit].cid
            for commit in bugfix_commit["bug_commit_hash"]
        ]


        res_cregit.append(bugfix_commit)
        res_original.append(original_bugfix_commit)
    except KeyError:
        print(
            f"KeyError on {bugfix_commit['repo_name']} {bugfix_commit['fix_commit_hash']}"
        )

with open(BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_2token.json", "w") as f:
    json.dump(res_cregit, f, indent=4)
# Out:
# apache/commons-cli
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# google/closure-compiler
# apache/commons-codec
# ...

# %% [markdown]
# N=3

# %%
import json
import sys
from pathlib import Path
sys.path.append(str(Path("../../../../")))
from research_szz_cregit.models.commit_map import CommitMap
from research_szz_cregit.repositories.commit_map.impl import CommitMapRepository
import copy

BASE_DIR = Path().resolve().parent.parent.parent.parent
DATABASE_DIR = BASE_DIR / "dataset" / "databases" / "developer-informed-oracle" / "3token"

with open(
    BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_original.json",
    "r",
) as f:
    bugfix_commits = json.load(f)

res_original = []
res_cregit = []

for bugfix_commit in bugfix_commits:
    original_bugfix_commit = copy.deepcopy(bugfix_commit)
    print(bugfix_commit["repo_name"])

    owner, project = bugfix_commit["repo_name"].split("/")

    commit_map_repository = CommitMapRepository(
        DATABASE_DIR / Path(f"{owner}/{project}/{project}-cregit.db")
    )

    commit_map = commit_map_repository.get_all()
    # cregit to original
    hashmaped_commit_map = CommitMap.get_cid_hashmap(commit_map)
    # original to cregit
    hashmaped_commit_map_from_original = CommitMap.get_cid_hashmap_from_original_cid(
        commit_map
    )

    try:
        bugfix_commit["fix_commit_hash"] = hashmaped_commit_map_from_original[
            bugfix_commit["fix_commit_hash"]
        ].cid
        bugfix_commit["bug_commit_hash"] = [
            hashmaped_commit_map_from_original[commit].cid
            for commit in bugfix_commit["bug_commit_hash"]
        ]


        res_cregit.append(bugfix_commit)
        res_original.append(original_bugfix_commit)
    except KeyError:
        print(
            f"KeyError on {bugfix_commit['repo_name']} {bugfix_commit['fix_commit_hash']}"
        )

with open(BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_3token.json", "w") as f:
    json.dump(res_cregit, f, indent=4)

# %% [markdown]
# N=4

# %%
import json
import sys
from pathlib import Path
sys.path.append(str(Path("../../../../")))
from research_szz_cregit.models.commit_map import CommitMap
from research_szz_cregit.repositories.commit_map.impl import CommitMapRepository
import copy

BASE_DIR = Path().resolve().parent.parent.parent.parent
DATABASE_DIR = BASE_DIR / "dataset" / "databases" / "developer-informed-oracle" / "4token"

with open(
    BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_original.json",
    "r",
) as f:
    bugfix_commits = json.load(f)

res_original = []
res_cregit = []

for bugfix_commit in bugfix_commits:
    original_bugfix_commit = copy.deepcopy(bugfix_commit)
    print(bugfix_commit["repo_name"])

    owner, project = bugfix_commit["repo_name"].split("/")

    commit_map_repository = CommitMapRepository(
        DATABASE_DIR / Path(f"{owner}/{project}/{project}-cregit.db")
    )

    commit_map = commit_map_repository.get_all()
    # cregit to original
    hashmaped_commit_map = CommitMap.get_cid_hashmap(commit_map)
    # original to cregit
    hashmaped_commit_map_from_original = CommitMap.get_cid_hashmap_from_original_cid(
        commit_map
    )

    try:
        bugfix_commit["fix_commit_hash"] = hashmaped_commit_map_from_original[
            bugfix_commit["fix_commit_hash"]
        ].cid
        bugfix_commit["bug_commit_hash"] = [
            hashmaped_commit_map_from_original[commit].cid
            for commit in bugfix_commit["bug_commit_hash"]
        ]


        res_cregit.append(bugfix_commit)
        res_original.append(original_bugfix_commit)
    except KeyError:
        print(
            f"KeyError on {bugfix_commit['repo_name']} {bugfix_commit['fix_commit_hash']}"
        )

with open(BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_4token.json", "w") as f:
    json.dump(res_cregit, f, indent=4)

# %% [markdown]
# N=5

# %%
import json
import sys
from pathlib import Path
sys.path.append(str(Path("../../../../")))
from research_szz_cregit.models.commit_map import CommitMap
from research_szz_cregit.repositories.commit_map.impl import CommitMapRepository
import copy

BASE_DIR = Path().resolve().parent.parent.parent.parent
DATABASE_DIR = BASE_DIR / "dataset" / "databases" / "developer-informed-oracle" / "5token"

with open(
    BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_original.json",
    "r",
) as f:
    bugfix_commits = json.load(f)

res_original = []
res_cregit = []

for bugfix_commit in bugfix_commits:
    original_bugfix_commit = copy.deepcopy(bugfix_commit)
    print(bugfix_commit["repo_name"])

    owner, project = bugfix_commit["repo_name"].split("/")

    commit_map_repository = CommitMapRepository(
        DATABASE_DIR / Path(f"{owner}/{project}/{project}-cregit.db")
    )

    commit_map = commit_map_repository.get_all()
    # cregit to original
    hashmaped_commit_map = CommitMap.get_cid_hashmap(commit_map)
    # original to cregit
    hashmaped_commit_map_from_original = CommitMap.get_cid_hashmap_from_original_cid(
        commit_map
    )

    try:
        bugfix_commit["fix_commit_hash"] = hashmaped_commit_map_from_original[
            bugfix_commit["fix_commit_hash"]
        ].cid
        bugfix_commit["bug_commit_hash"] = [
            hashmaped_commit_map_from_original[commit].cid
            for commit in bugfix_commit["bug_commit_hash"]
        ]


        res_cregit.append(bugfix_commit)
        res_original.append(original_bugfix_commit)
    except KeyError:
        print(
            f"KeyError on {bugfix_commit['repo_name']} {bugfix_commit['fix_commit_hash']}"
        )

with open(BASE_DIR
    / "dataset"
    / "pyszz_v2"
    / "json-input-raw"
    / "developer-informed-oracle"
    / "d4j_bugfix_commits_5token.json", "w") as f:
    json.dump(res_cregit, f, indent=4)
